# %%
import pandas as pd
import numpy as np
import os

# %%
print(os.getcwd())
# Out:
# d:\code

# %%
import config
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-75286f0caaeb> in <module>
# ----> 1 import config
#
# ModuleNotFoundError: No module named 'config'
