# %%
import pandas as pd
import numpy as np
import os
append_feature=pd.read_csv('Datasets/Xiamen_data/split/train/feature/append_feature.csv')

# %%
row_size = append_feature.shape[1]
multiply = rd.randint(0, 2)
simbol = rd.randint(0, 1)
random_data=np.random.random(row_size)
